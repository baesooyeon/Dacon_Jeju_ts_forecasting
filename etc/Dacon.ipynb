# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
trade  = pd.read_csv("international_trade.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
sample
# Out:
#                    ID  answer
# 0     TG_A_J_20230304       0
# 1     TG_A_J_20230305       0
# 2     TG_A_J_20230306       0
# 3     TG_A_J_20230307       0
# 4     TG_A_J_20230308       0
# ...               ...     ...
# 1087  RD_F_J_20230327       0
# 1088  RD_F_J_20230328       0
# 1089  RD_F_J_20230329       0
# 1090  RD_F_J_20230330       0
# 1091  RD_F_J_20230331       0
#
# [1092 rows x 2 columns]

# %%
trade
# Out:
#            기간                              품목명    수출 중량  수출 금액    수입 중량  \
# 0     2019-01        토마토(신선한 것이나 냉장한 것으로 한정한다)   356571    990        0
# 1     2019-01                               양파   821330    222  4003206
# 2     2019-01                               쪽파       60      1    93405
# 3     2019-01             꽃양배추와 브로콜리(broccoli)      160      1   638913
# 4     2019-01                        방울다다기 양배추        0      0     7580
# ...       ...                              ...      ...    ...      ...
# 1269  2023-02           포포(papaw)[파파야(papaya)]        0      0    23830
# 1270  2023-02                               사과   135165    351        0
# 1271  2023-02                                배  2206012   5411        1
# 1272  2023-02  신 체리[프루너스 체라서스(Prunus cerasus)]        5      0        0
# 1273  2023-02                               자두        0      0        2
#
#       수입 금액  무역수지
# 0         0   990
# 1      1118  -896
# 2       128  -127
# 3       563  -562
# 4        38   -38
# ...     ...   ...
# 1269     71   -71
# 1270      0   351
# 1271      0  5411
# 1272      0     0
# 1273      0     0
#
# [1274 rows x 7 columns]

# %%
df
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 0      TG_A_J_20190101  2019-01-01   TG           A        J         0.0
# 1      TG_A_J_20190102  2019-01-02   TG           A        J         0.0
# 2      TG_A_J_20190103  2019-01-03   TG           A        J     60601.0
# 3      TG_A_J_20190104  2019-01-04   TG           A        J     25000.0
# 4      TG_A_J_20190105  2019-01-05   TG           A        J     32352.0
# ...                ...         ...  ...         ...      ...         ...
# 59392  RD_F_J_20230227  2023-02-27   RD           F        J    452440.0
# 59393  RD_F_J_20230228  2023-02-28   RD           F        J    421980.0
# 59394  RD_F_J_20230301  2023-03-01   RD           F        J    382980.0
# 59395  RD_F_J_20230302  2023-03-02   RD           F        J    477220.0
# 59396  RD_F_J_20230303  2023-03-03   RD           F        J    427520.0
#
#        price(원/kg)
# 0              0.0
# 1              0.0
# 2           1728.0
# 3           1408.0
# 4           1250.0
# ...            ...
# 59392        468.0
# 59393        531.0
# 59394        574.0
# 59395        523.0
# 59396        529.0
#
# [59397 rows x 7 columns]

# %%
trade[["기간", "품목명"]].groupby("품목명").count()
# Out:
#                                                     기간
# 품목명
# 감귤                                                  50
# 결구(結球) 상추                                           50
# 구아바(guava)                                          23
# 그레이프프루트(grapefruit)와 포멜로(pomelo)                    50
# 꽃양배추와 브로콜리(broccoli)                                50
# 당근                                                  50
# 대추야자                                                50
# 레몬[시트러스 리몬(Citrus limon)ㆍ시트러스 리머늄(Citrus limonum)]  50
# 망고(mango)                                           50
# 망고스틴(mangosteen)                                    42
# 무화과                                                 50
# 방울다다기 양배추                                           50
# 방울토마토                                               14
# 배                                                   50
# 복숭아[넥터린(nectarine)을 포함한다]                           23
# 사과                                                  50
# 살구                                                  15
# 샬롯(shallot)                                         14
# 수박                                                  49
# 순무                                                   6
# 신 체리[프루너스 체라서스(Prunus cerasus)]                     16
# 양배추                                                 50
# 양파                                                  42
# 오렌지                                                 50
# 오이류(신선한 것이나 냉장한 것으로 한정한다)                           50
# 완두[피섬 새티범(Pisum sativum)]                           11
# 위트루프 치커리(Witloof chicory)[시코리엄 인티부스 변종 포리오섬(Cic...  22
# 자두                                                  39
# 쪽파                                                  36
# 참외                                                  11
# 콩[비그나(Vigna)속ㆍ파세러스(Phaseolus)속)]                    25
# 토마토(신선한 것이나 냉장한 것으로 한정한다)                           36
# 파인애플                                                50
# 포포(papaw)[파파야(papaya)]                              50

# %% [markdown]
# # EDA

# %%
# 우리가 예측해야하는 것들 >> 품목+법인+지역만 해도 38개...
df[["item","corporation", "location"]].groupby(["item", "corporation", "location"]).count().reset_index()
# Out:
#    item corporation location
# 0    BC           A        J
# 1    BC           A        S
# 2    BC           B        J
# 3    BC           B        S
# 4    BC           C        J
# 5    BC           C        S
# 6    BC           D        J
# 7    BC           E        J
# 8    BC           E        S
# 9    CB           A        J
# 10   CB           A        S
# 11   CB           D        J
# 12   CB           E        J
# 13   CB           F        J
# 14   CR           A        J
# 15   CR           B        J
# 16   CR           C        J
# 17   CR           D        J
# 18   CR           D        S
# 19   CR           E        J
# 20   CR           E        S
# 21   RD           A        J
# 22   RD           A        S
# 23   RD           C        S
# 24   RD           D        J
# 25   RD           D        S
# 26   RD           E        J
# 27   RD           E        S
# 28   RD           F        J
# 29   TG           A        J
# 30   TG           A        S
# 31   TG           B        J
# 32   TG           B        S
# 33   TG           C        J
# 34   TG           C        S
# 35   TG           D        J
# 36   TG           D        S
# 37   TG           E        J
# 38   TG           E        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59397 entries, 0 to 59396
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           59397 non-null  object
#  1   timestamp    59397 non-null  object
#  2   item         59397 non-null  object
#  3   corporation  59397 non-null  object
#  4   location     59397 non-null  object
#  5   supply(kg)   59397 non-null  float64
#  6   price(원/kg)  59397 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 3.2+ MB

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59397 entries, 0 to 59396
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           59397 non-null  object
#  1   timestamp    59397 non-null  datetime64[ns]
#  2   item         59397 non-null  object
#  3   corporation  59397 non-null  object
#  4   location     59397 non-null  object
#  5   supply(kg)   59397 non-null  float64
#  6   price(원/kg)  59397 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 3.2+ MB

# %% [markdown]
# ### 농산물 별 EDA

# %%
from matplotlib import rc
import platform

if platform.system() == 'Windows':
    rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    rc('font', family='AppleGothic')
else: #linux
    rc('font', family='NanumGothic')
    
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 현상 해결 코드

# %%
df.item.unique()
# Out:
# array(['TG', 'CR', 'CB', 'RD', 'BC'], dtype=object)

# %%
plt.scatter(df[df["item"] == "TG"]["timestamp"], df[df["item"] == "TG"]["price(원/kg)"])

# %%
f, axes  = plt.subplots(2,3)
f.set_size_inches((20,15))

axes[0,0].plot(df[df["item"] == "TG"]["timestamp"], df[df["item"] == "TG"]["price(원/kg)"])
axes[0,0].set_title("감귤 가격 그래프")

axes[0,1].plot(df[df["item"] == "CR"]["timestamp"], df[df["item"] == "CR"]["price(원/kg)"])
axes[0,1].set_title("당근 가격 그래프")

axes[0,2].plot(df[df["item"] == "CB"]["timestamp"], df[df["item"] == "CB"]["price(원/kg)"])
axes[0,2].set_title("양배추 가격 그래프")

axes[1,0].plot(df[df["item"] == "RD"]["timestamp"], df[df["item"] == "RD"]["price(원/kg)"])
axes[1,0].set_title("무 가격 그래프")

axes[1,1].plot(df[df["item"] == "BC"]["timestamp"], df[df["item"] == "BC"]["price(원/kg)"])
axes[1,1].set_title("브로콜리 가격 그래프")
# Out:
# Text(0.5, 1.0, '브로콜리 가격 그래프')

# %%
df[df["item"] == "BC"]["price(원/kg)"]
# Out:
# 42644       0.0
# 42645       0.0
# 42646    2559.0
# 42647    2425.0
# 42648    2097.0
#           ...
# 56346    2488.0
# 56347    3232.0
# 56348    3816.0
# 56349    3321.0
# 56350    2939.0
# Name: price(원/kg), Length: 13707, dtype: float64

# %%
nongsan
# Out:
# ['RD', 'TG', 'BC', 'CR', 'CB']

# %%
nongsan = []
for i in set(df["item"].tolist()):
    nongsan.append(i)

nongsan_price = []
for i in nongsan:
    nongsan_price.append(df[df["item"]==i]["price(원/kg)"].tolist())

# %%
import seaborn as sns
sns.boxplot(nongsan_price)
# Out:
# <Axes: >

# %%
price.iloc[1]
# Out:
# 375.0

# %%
df[df["price(원/kg)"] ==price.iloc[1]]
# Out:
#                     ID  timestamp item corporation location  supply(kg)  \
# 31549  CB_E_J_20211225 2021-12-25   CB           E        J       432.0
# 32036  RD_A_J_20190223 2019-02-23   RD           A        J      8560.0
# 32446  RD_A_J_20200408 2020-04-08   RD           A        J     42180.0
# 33155  RD_A_J_20220318 2022-03-18   RD           A        J      4460.0
# 33929  RD_A_S_20200228 2020-02-28   RD           A        S     25360.0
# 34345  RD_A_S_20210419 2021-04-19   RD           A        S     98960.0
# 35787  RD_C_S_20210128 2021-01-28   RD           C        S     17200.0
# 36527  RD_C_S_20230207 2023-02-07   RD           C        S      4300.0
# 36629  RD_D_J_20190319 2019-03-19   RD           D        J      4280.0
# 37335  RD_D_J_20210222 2021-02-22   RD           D        J     13980.0
# 38180  RD_D_S_20190416 2019-04-16   RD           D        S     32600.0
# 39282  RD_D_S_20220422 2022-04-22   RD           D        S     15040.0
# 39679  RD_E_J_20190323 2019-03-23   RD           E        J      8620.0
# 39682  RD_E_J_20190326 2019-03-26   RD           E        J     16160.0
# 39703  RD_E_J_20190416 2019-04-16   RD           E        J      4300.0
# 40060  RD_E_J_20200407 2020-04-07   RD           E        J      4300.0
# 40061  RD_E_J_20200408 2020-04-08   RD           E        J      9680.0
# 41128  RD_E_S_20190108 2019-01-08   RD           E        S      4300.0
# 41135  RD_E_S_20190115 2019-01-15   RD           E        S      8620.0
# 41136  RD_E_S_20190116 2019-01-16   RD           E        S      3220.0
# 41227  RD_E_S_20190417 2019-04-17   RD           E        S      4300.0
# 49908  BC_C_J_20220318 2022-03-18   BC           C        J        64.0
# 55854  BC_E_S_20211023 2021-10-23   BC           E        S       240.0
# 58774  RD_F_J_20210619 2021-06-19   RD           F        J     42020.0
# 58776  RD_F_J_20210621 2021-06-21   RD           F        J     74940.0
#
#        price(원/kg)
# 31549        375.0
# 32036        375.0
# 32446        375.0
# 33155        375.0
# 33929        375.0
# 34345        375.0
# 35787        375.0
# 36527        375.0
# 36629        375.0
# 37335        375.0
# 38180        375.0
# 39282        375.0
# 39679        375.0
# 39682        375.0
# 39703        375.0
# 40060        375.0
# 40061        375.0
# 41128        375.0
# 41135        375.0
# 41136        375.0
# 41227        375.0
# 49908        375.0
# 55854        375.0
# 58774        375.0
# 58776        375.0
